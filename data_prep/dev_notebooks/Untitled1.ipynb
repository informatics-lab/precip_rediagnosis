# %%
import os
import pathlib

# %%
import pandas

# %%
data_path_storm_dennis = pathlib.Path('/project/informatics_lab/precip_rediagnosis/train202208/202002_storm_dennis/prd_merged_20200214T1800Z_20200217T1800Z.csv')
data_path_storm_dennis
# Out:
# PosixPath('/project/informatics_lab/precip_rediagnosis/train202208/202002_storm_dennis/prd_merged_20200214T1800Z_20200217T1800Z.csv')

# %%
storm_dennis_df = pandas.read_csv(data_path_storm_dennis)

# %%
storm_dennis_df
# Out:
#                        time  latitude  longitude  \
# 0       2020-02-14 18:00:00  49.40625  -5.484375
# 1       2020-02-14 18:00:00  49.40625  -5.484375
# 2       2020-02-14 18:00:00  49.40625  -5.484375
# 3       2020-02-14 18:00:00  49.40625  -5.484375
# 4       2020-02-14 18:00:00  49.40625  -5.484375
# ...                     ...       ...        ...
# 347251  2020-02-17 18:00:00  58.78125   1.546875
# 347252  2020-02-17 18:00:00  58.78125   1.546875
# 347253  2020-02-17 18:00:00  58.78125   1.546875
# 347254  2020-02-17 18:00:00  58.78125   1.546875
# 347255  2020-02-17 18:00:00  58.78125   1.546875
#
#         radar_max_rain_aggregate_3hr  radar_mean_rain_aggregate_3hr  \
# 0                           3.143229                       2.235472
# 1                           3.143229                       2.235472
# 2                           3.143229                       2.235472
# 3                           3.143229                       2.235472
# ...

# %%
sum(storm_dennis_df['time'].value_counts())
# Out:
# 347256

# %%
sum(storm_dennis_df['time'].isna())
# Out:
# 0
